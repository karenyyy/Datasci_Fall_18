# %% [markdown]
# ### import packages

# %%
import datascience as ds
from datascience import *
import numpy as np
from graphviz import Source
import pandas as pd
import seaborn as sns
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer, TfidfVectorizer
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn import tree
import gensim
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score, accuracy_score, classification_report
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, cross_val_score, StratifiedKFold
from sklearn.externals import joblib
import tensorflow as tf
import tensorflow_hub as hub
# %matplotlib inline

# %% [markdown]
# ### tweets data

# %% [markdown]
# #### climate

# %%
df = pd.read_csv('Climate1SupportiveLevel.csv', sep=',')
df
# Out:
#       Unnamed: 0                        ID  \
# 0              0   962_Cleand_Climate1.csv
# 1              1   885_Cleand_Climate1.csv
# 2              2   680_Cleand_Climate1.csv
# 3              3  1152_Cleand_Climate1.csv
# 4              4   731_Cleand_Climate1.csv
# 5              5  1075_Cleand_Climate1.csv
# 6              6    85_Cleand_Climate1.csv
# 7              7   654_Cleand_Climate1.csv
# 8              8   916_Cleand_Climate1.csv
# 9              9   372_Cleand_Climate1.csv
# 10            10   839_Cleand_Climate1.csv
# 11            11  1106_Cleand_Climate1.csv
# 12            12   295_Cleand_Climate1.csv
# 13            13   557_Cleand_Climate1.csv
# 14            14  1029_Cleand_Climate1.csv
# 15            15    39_Cleand_Climate1.csv
# 16            16   608_Cleand_Climate1.csv
# 17            17   403_Cleand_Climate1.csv
# 18            18   198_Cleand_Climate1.csv
# 19            19   326_Cleand_Climate1.csv
# 20            20   121_Cleand_Climate1.csv
# 21            21   249_Cleand_Climate1.csv
# 22            22   931_Cleand_Climate1.csv
# 23            23  1275_Cleand_Climate1.csv
# 24            24  1070_Cleand_Climate1.csv
# 25            25    80_Cleand_Climate1.csv
# 26            26   854_Cleand_Climate1.csv
# 27            27  1198_Cleand_Climate1.csv
# 28            28  1121_Cleand_Climate1.csv
# 29            29   777_Cleand_Climate1.csv
# ...          ...                       ...
# 1253        1253  1014_Cleand_Climate1.csv
# 1254        1254    24_Cleand_Climate1.csv
# 1255        1255   331_Cleand_Climate1.csv
# 1256        1256   388_Cleand_Climate1.csv
# 1257        1257   516_Cleand_Climate1.csv
# 1258        1258   311_Cleand_Climate1.csv
# 1259        1259   439_Cleand_Climate1.csv
# 1260        1260   234_Cleand_Climate1.csv
# 1261        1261   157_Cleand_Climate1.csv
# 1262        1262  1280_Cleand_Climate1.csv
# 1263        1263  1260_Cleand_Climate1.csv
# 1264        1264  1183_Cleand_Climate1.csv
# 1265        1265   967_Cleand_Climate1.csv
# 1266        1266   762_Cleand_Climate1.csv
# 1267        1267  1234_Cleand_Climate1.csv
# 1268        1268   685_Cleand_Climate1.csv
# 1269        1269   480_Cleand_Climate1.csv
# 1270        1270   813_Cleand_Climate1.csv
# 1271        1271  1157_Cleand_Climate1.csv
# 1272        1272   531_Cleand_Climate1.csv
# 1273        1273  1137_Cleand_Climate1.csv
# 1274        1274   454_Cleand_Climate1.csv
# 1275        1275   716_Cleand_Climate1.csv
# 1276        1276   172_Cleand_Climate1.csv
# 1277        1277   639_Cleand_Climate1.csv
# 1278        1278   434_Cleand_Climate1.csv
# 1279        1279   357_Cleand_Climate1.csv
# 1280        1280   408_Cleand_Climate1.csv
# 1281        1281   203_Cleand_Climate1.csv
# 1282        1282   126_Cleand_Climate1.csv
#
#                                                    Text  SupportiveLabel
# 0     RT @kasserolees: Energy is the #1 contributer ...                1
# 1     RT @edelman_barbara: @msnbc why don t you have...                1
# 2     RT @OtagoGrad: @anthonyfurey @OskieOckham The ...                0
# 3     The Dow just recorded its 3rd worst day ever. ...                0
# 4     RT @SimonBanksHB: I am not going to rule out t...                0
# 5     RT @sydneyleemarco: nothing like an 80 degree ...                1
# 6     @MerlenesMemos @CNN It's not an act of god. Cl...                1
# 7     RT @MikeLevinCA: When asked about climate chan...                0
# 8     RT @gq_jayq: Bet I got 11 years to run it up h...                0
# 9               No they care about the oil billionaires                0
# 10    RT @cathmckenna: The best that science has to ...                0
# 11    RT @tumblindice1979: @elizabethforma @algore I...                0
# 12    Global Warming and climate control is fake. GL...                0
# 13    RT @HazelMonforton: Literally none of these th...                0
# 14    RT @pimpnsincebirth: How about you end corpora...                0
# 15    @BjornLomborg I think looking at climate chang...                1
# 16    RT @KateRaworth: If you feel the dissonance be...                1
# 17    RT @4everlung: Each year about 13 million hect...                0
# 18    @tracyajonas @David_Leavitt @realDonaldTrump i...                0
# 19    I cannot find one attribute that qualifies thi...                1
# 20    @Weinsteinlaw His base doesn t care. unaffilia...                1
# 21    Climate change takes a chronic psychological t...                0
# 22    RT @idea2go: The definition of #ClimateBreakdo...                1
# 23    sexy I don't die of natural causes at least a ...                1
# 24    RT @smilon713: I wish NO harm to those in red ...                1
# 25    @LynchpinL With climate change making the worl...                1
# 26    RT @cottoncandaddy: oh so we re like dead dead...                0
# 27    Trump on climate change report: 'I want to loo...                1
# 28    RT @yeson1631: .@VanJones68 all the life we kn...                1
# 29    RT @VABVOX: Harrowing. And while I'm sure some...                0
# ...                                                 ...              ...
# 1253  RT @nowthisnews: A bombshell report from the U...                1
# 1254  3/Their existing problems are going to get wor...                1
# 1255  I have an idea how about we start by legalizin...                1
# 1256  People are idiots sometimes. #ErieRally #Trump...                0
# 1257  RT @EnergyBoom: Explaining the #IPCC #SR15 rep...                1
# 1258  Hi @airscottdenning! I'm on a faculty fellowsh...                1
# 1259  RT @BrettKeagle: Y all really think climate ch...                1
# 1260  Care to Click follows @RAN - Have you clicked ...                0
# 1261  @hemitruck1234 @Bakari_Sellers @RealCandaceO T...                0
# 1262   there might not be a tomorrow. let that sink in.                0
# 1263  every issue we devote attention to other than ...                0
# 1264  This morning we re at the Strengthening Commun...                1
# 1265  RT @kenolin1: Donald Trump calls Russian inter...                0
# 1266  RT @TorontoStar: More sweltering hot days. Mor...                1
# 1267  Will Victoria s political parties announce vis...                1
# 1268  RT @Paola_Dec1231: WE ARE ALL GONNA DIE! No se...                0
# 1269  RT @ConversationUS: Don't be afraid to talk ab...                1
# 1270  RT @andizeisler: I really want to know who the...                1
# 1271  The chips are down in Europe... a small foresh...                1
# 1272  RT @GISP_Tweets: The Intergovernmental Panel o...                1
# 1273  Sexy collapse of civilization from runaway cli...                0
# 1274  RT @CainTess: We believe Australia is failing ...                1
# 1275  RT @Saycheese_Media: Scientists announced a wa...                1
# 1276  @neiltyson @neiltyson thank you for reminding ...                0
# 1277  RT @MarketUrbanism: I'm supposed to look at th...                1
# 1278  RT @BjayukCat: @tumblindice1979 @elizabethform...                1
# 1279  It's urgent to put Saskatoon's climate change ...                1
# 1280  RT @Alex_Verbeek: Today in Geneva where I spok...                1
# 1281  @wordcipher @CNN Because climate change has no...                0
# 1282  @WhiteHouse @realDonaldTrump @SecNielsen @FEMA...                0
#
# [1283 rows x 4 columns]

# %% [markdown]
# #### sentiment 140

# %%
df = pd.read_csv('/home/karen/Downloads/training.1600000.processed.noemoticon.csv', sep=',', encoding='latin-1')
df.columns = ['target', 'ids', 'date', 'flag', 'user', 'text']
df.target = df.target.replace(4,1)
df
# Out:
#          target         ids                          date      flag  \
# 0             0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 1             0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 2             0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 3             0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4             0  1467811372  Mon Apr 06 22:20:00 PDT 2009  NO_QUERY
# 5             0  1467811592  Mon Apr 06 22:20:03 PDT 2009  NO_QUERY
# 6             0  1467811594  Mon Apr 06 22:20:03 PDT 2009  NO_QUERY
# 7             0  1467811795  Mon Apr 06 22:20:05 PDT 2009  NO_QUERY
# 8             0  1467812025  Mon Apr 06 22:20:09 PDT 2009  NO_QUERY
# 9             0  1467812416  Mon Apr 06 22:20:16 PDT 2009  NO_QUERY
# 10            0  1467812579  Mon Apr 06 22:20:17 PDT 2009  NO_QUERY
# 11            0  1467812723  Mon Apr 06 22:20:19 PDT 2009  NO_QUERY
# 12            0  1467812771  Mon Apr 06 22:20:19 PDT 2009  NO_QUERY
# 13            0  1467812784  Mon Apr 06 22:20:20 PDT 2009  NO_QUERY
# 14            0  1467812799  Mon Apr 06 22:20:20 PDT 2009  NO_QUERY
# 15            0  1467812964  Mon Apr 06 22:20:22 PDT 2009  NO_QUERY
# 16            0  1467813137  Mon Apr 06 22:20:25 PDT 2009  NO_QUERY
# 17            0  1467813579  Mon Apr 06 22:20:31 PDT 2009  NO_QUERY
# 18            0  1467813782  Mon Apr 06 22:20:34 PDT 2009  NO_QUERY
# 19            0  1467813985  Mon Apr 06 22:20:37 PDT 2009  NO_QUERY
# 20            0  1467813992  Mon Apr 06 22:20:38 PDT 2009  NO_QUERY
# 21            0  1467814119  Mon Apr 06 22:20:40 PDT 2009  NO_QUERY
# 22            0  1467814180  Mon Apr 06 22:20:40 PDT 2009  NO_QUERY
# 23            0  1467814192  Mon Apr 06 22:20:41 PDT 2009  NO_QUERY
# 24            0  1467814438  Mon Apr 06 22:20:44 PDT 2009  NO_QUERY
# 25            0  1467814783  Mon Apr 06 22:20:50 PDT 2009  NO_QUERY
# 26            0  1467814883  Mon Apr 06 22:20:52 PDT 2009  NO_QUERY
# 27            0  1467815199  Mon Apr 06 22:20:56 PDT 2009  NO_QUERY
# 28            0  1467815753  Mon Apr 06 22:21:04 PDT 2009  NO_QUERY
# 29            0  1467815923  Mon Apr 06 22:21:07 PDT 2009  NO_QUERY
# ...         ...         ...                           ...       ...
# 1599969       1  2193578196  Tue Jun 16 08:38:54 PDT 2009  NO_QUERY
# 1599970       1  2193578237  Tue Jun 16 08:38:54 PDT 2009  NO_QUERY
# 1599971       1  2193578269  Tue Jun 16 08:38:54 PDT 2009  NO_QUERY
# 1599972       1  2193578319  Tue Jun 16 08:38:55 PDT 2009  NO_QUERY
# 1599973       1  2193578345  Tue Jun 16 08:38:55 PDT 2009  NO_QUERY
# 1599974       1  2193578347  Tue Jun 16 08:38:55 PDT 2009  NO_QUERY
# 1599975       1  2193578348  Tue Jun 16 08:38:55 PDT 2009  NO_QUERY
# 1599976       1  2193578386  Tue Jun 16 08:38:55 PDT 2009  NO_QUERY
# 1599977       1  2193578395  Tue Jun 16 08:38:55 PDT 2009  NO_QUERY
# 1599978       1  2193578576  Tue Jun 16 08:38:57 PDT 2009  NO_QUERY
# 1599979       1  2193578679  Tue Jun 16 08:38:56 PDT 2009  NO_QUERY
# 1599980       1  2193578716  Tue Jun 16 08:38:57 PDT 2009  NO_QUERY
# 1599981       1  2193578739  Tue Jun 16 08:38:57 PDT 2009  NO_QUERY
# 1599982       1  2193578758  Tue Jun 16 08:38:57 PDT 2009  NO_QUERY
# 1599983       1  2193578847  Tue Jun 16 08:38:57 PDT 2009  NO_QUERY
# 1599984       1  2193578982  Tue Jun 16 08:38:58 PDT 2009  NO_QUERY
# 1599985       1  2193579087  Tue Jun 16 08:38:58 PDT 2009  NO_QUERY
# 1599986       1  2193579092  Tue Jun 16 08:38:58 PDT 2009  NO_QUERY
# 1599987       1  2193579191  Tue Jun 16 08:38:59 PDT 2009  NO_QUERY
# 1599988       1  2193579211  Tue Jun 16 08:38:59 PDT 2009  NO_QUERY
# 1599989       1  2193579249  Tue Jun 16 08:38:59 PDT 2009  NO_QUERY
# 1599990       1  2193579284  Tue Jun 16 08:38:59 PDT 2009  NO_QUERY
# 1599991       1  2193579434  Tue Jun 16 08:39:00 PDT 2009  NO_QUERY
# 1599992       1  2193579477  Tue Jun 16 08:39:00 PDT 2009  NO_QUERY
# 1599993       1  2193579489  Tue Jun 16 08:39:00 PDT 2009  NO_QUERY
# 1599994       1  2193601966  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599995       1  2193601969  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599996       1  2193601991  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599997       1  2193602064  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599998       1  2193602129  Tue Jun 16 08:40:50 PDT 2009  NO_QUERY
#
#                     user                                               text
# 0          scotthamilton  is upset that he can't update his Facebook by ...
# 1               mattycus  @Kenichan I dived many times for the ball. Man...
# 2                ElleCTF    my whole body feels itchy and like its on fire
# 3                 Karoli  @nationwideclass no, it's not behaving at all....
# 4               joy_wolf                      @Kwesidei not the whole crew
# 5                mybirch                                        Need a hug
# 6                   coZZ  @LOLTrish hey  long time no see! Yes.. Rains a...
# 7        2Hood4Hollywood               @Tatiana_K nope they didn't have it
# 8                mimismo                          @twittera que me muera ?
# 9         erinx3leannexo        spring break in plain city... it's snowing
# 10          pardonlauren                         I just re-pierced my ears
# 11                  TLeC  @caregiving I couldn't bear to watch it.  And ...
# 12       robrobbierobert  @octolinz16 It it counts, idk why I did either...
# 13           bayofwolves  @smarrison i would've been the first, but i di...
# 14            HairByJess  @iamjazzyfizzle I wish I got to watch it with ...
# 15        lovesongwriter  Hollis' death scene will hurt me severely to w...
# 16              armotley                               about to file taxes
# 17            starkissed  @LettyA ahh ive always wanted to see rent  lov...
# 18             gi_gi_bee  @FakerPattyPattz Oh dear. Were you drinking ou...
# 19                quanvu  @alydesigns i was out most of the day so didn'...
# 20            swinspeedx  one of my friend called me, and asked to meet ...
# 21             cooliodoc   @angry_barista I baked you a cake but I ated it
# 22            viJILLante             this week is not going as i had hoped
# 23            Ljelli3166                         blagh class at 8 tomorrow
# 24         ChicagoCubbie     I hate when I have to call and wake people up
# 25           KatieAngell  Just going to cry myself to sleep after watchi...
# 26                 gagoo                             im sad now  Miss.Lilly
# 27               abel209  ooooh.... LOL  that leslie.... and ok I won't ...
# 28       BaptisteTheFool  Meh... Almost Lover is the exception... this t...
# 29             fatkat309  some1 hacked my account on aim  now i have to ...
# ...                  ...                                                ...
# 1599969    adbillingsley  Thanks @eastwestchic &amp; @wangyip Thanks! Th...
# 1599970           gekkko  @marttn thanks Martin. not the most imaginativ...
# 1599971       millerslab          @MikeJonesPhoto Congrats Mike  Way to go!
# 1599972  luckygeorgeblog  http://twitpic.com/7jp4n - OMG! Office Space.....
# 1599973    Kristah_Diggs  @yrclndstnlvr ahaha nooo you were just away fr...
# 1599974        CoachChic  @BizCoachDeb  Hey, I'm baack! And, thanks so m...
# 1599975         serianna  @mattycus Yeah, my conscience would be clear i...
# 1599976   TeamUKskyvixen  @MayorDorisWolfe Thats my girl - dishing out t...
# 1599977      LaurenMoo10                          @shebbs123 i second that
# 1599978    angel_sammy04                                     In the garden
# 1599979        puchal_ek  @myheartandmind jo jen by nemuselo zrovna t̩ ...
# 1599980    youtubelatest  Another Commenting Contest! [;: Yay!!!  http:/...
# 1599981  Mandi_Davenport  @thrillmesoon i figured out how to see my twee...
# 1599982         xoAurixo  @oxhot theri tomorrow, drinking coffee, talkin...
# 1599983       RobFoxKerr  You heard it here first -- We're having a girl...
# 1599984         LISKFEST  if ur the lead singer in a band, beware fallin...
# 1599985          marhgil              @tarayqueen too much ads on my blog.
# 1599986        cathriiin  @La_r_a NEVEER  I think that you both will get...
# 1599987          tellman  @Roy_Everitt ha- good job. that's right - we g...
# 1599988        jazzstixx                 @Ms_Hip_Hop im glad ur doing well
# 1599989    razzberry5594                              WOOOOO! Xbox is back
# 1599990        AgustinaP  @rmedina @LaTati Mmmm  That sounds absolutely ...
# 1599991    sdancingsteph                  ReCoVeRiNg FrOm ThE lOnG wEeKeNd
# 1599992      ChloeAmisha                                  @SCOOBY_GRITBOYS
# 1599993        EvolveTom  @Cliff_Forster Yeah, that does work better tha...
# 1599994  AmandaMarie1028  Just woke up. Having no school is the best fee...
# 1599995      TheWDBoards  TheWDB.com - Very cool to hear old Walt interv...
# 1599996           bpbabe  Are you ready for your MoJo Makeover? Ask me f...
# 1599997     tinydiamondz  Happy 38th Birthday to my boo of alll time!!! ...
# 1599998   RyanTrevMorris  happy #charitytuesday @theNSPCC @SparksCharity...
#
# [1599999 rows x 6 columns]

# %% [markdown]
# ### Preprocess

# %% [markdown]
# #### climate

# %%
X = list(df['Text'])
y = list(df['SupportiveLabel'])

# %% [markdown]
# #### sentiment 140

# %%
X = df['text']
y = df['target']

# %% [markdown]
# ### Check whether the data distribution is balanced

# %%
def check(sentiment, index, y_col, note='training'):
    if sentiment==0:
        label = 'negative'
    else:
        label = 'positive'
    df_partial = df.take(index)
    print('There are {} '.format(df_partial[df_partial[y_col]==sentiment].shape[0])+label+' tweets in the '+note+' set.')

# %% [markdown]
# ### split

# %%
def custom_split(train_index, test_index, x_col, y_col):
    trainingset = df.take(train_index)
    testingset = df.take(test_index)    
        
    X_train= list(trainingset[x_col])
    y_train= list(trainingset[y_col])
    X_test= list(testingset[x_col])
    y_test= list(testingset[y_col])
    
    return X_train, X_test, y_train, y_test

# %% [markdown]
# ### Models

# %%
class  TfIdfWord2VecVectorizer:
    def __init__(self):
        pass

    def fit(self, X, y):
        self.tfidf_model = TfidfVectorizer(min_df=3, max_df=50000).fit(X)
        return self

    def transform(self, X):
        return self.tfidf_and_w2v(X, self.tfidf_model)

    def texts_encoder(self, texts):
        with tf.Graph().as_default():
            embed = hub.Module("https://tfhub.dev/google/nnlm-en-dim128/1")
            embeddings = embed(texts)
            with tf.Session() as sess:
                sess.run(tf.global_variables_initializer())
                sess.run(tf.tables_initializer())
                result = sess.run(embeddings)
        return result

    def tfidf_and_w2v(self, X, tfidf_model):
        tmp = tfidf_model.transform(X)
        a = tmp.toarray()
        if isinstance(X, pd.core.series.Series):
            X = X.tolist()
        b = self.texts_encoder(X)
        return np.hstack((a, b))

# %% [markdown]
# ### classifier

# %%
def classifier(X_train, y_train, X_test, fold, vect, clf):
    # token_pattern='(([#@]|[0-9]|[a-z]|[A-Z])+)'
    clf = Pipeline(
        [
            ('vect', vect),
            ('clf', clf)
        ])
    clf.fit(X_train, y_train)
    predicted_y_test = clf.predict(X_test)
    # save as pickle
    # joblib.dump(clf, 'ClimateTeam7PD1.pkl')
    return predicted_y_test

# %%
c=CountVectorizer(token_pattern="(?!RT|rt|\d+)[@#]*[\w\'_-]{2,100}",
                                     analyzer = 'word',
                                     stop_words='english',
                                     min_df = 3)
c.fit(X, y)
c.get_feature_names()
# Out:
# ['#1o5c',
#  '#actonclimate',
#  '#auspol',
#  '#cdnpoli',
#  '#climate',
#  '#climateaction',
#  '#climatebreakdown',
#  '#climatechange',
#  '#climatechangeisreal',
#  '#climateimpactsvic',
#  '#dems',
#  '#emissions',
#  '#energy',
#  '#environment',
#  '#florida',
#  '#forests',
#  '#globalwarming',
#  '#gop',
#  '#hurricanemichael',
#  '#hurricanemichael2018',
#  '#ipcc',
#  '#ipccreport',
#  '#liberals',
#  '#michael',
#  '#nets',
#  '#nswpol',
#  '#onpoli',
#  '#qldpol',
#  '#science',
#  '#solar',
#  '#sr15',
#  '#stopadani',
#  '#sustainability',
#  '#topoli',
#  '#trump',
#  '#weather',
#  '#wentworthbyelection',
#  '#wentworthvotes',
#  "'climate",
#  "'fabulous'",
#  '--',
#  '-year',
#  '@algore',
#  '@andrewgillum',
#  '@atrupar',
#  '@c40cities',
#  '@carolinelucas',
#  '@cathmckenna',
#  '@chrisjzullo',
#  '@chriskkenny',
#  '@cnn',
#  '@davesharma',
#  '@david_leavitt',
#  '@didikins4life',
#  '@dtdchange',
#  '@edwardjwhunter',
#  '@elizabethforma',
#  '@ericholthaus',
#  '@esa_org',
#  '@extinctsymbol',
#  '@fema',
#  '@fema_brock',
#  '@flgovscott',
#  '@fordnation',
#  '@foxnews',
#  '@gdillin',
#  '@georgemonbiot',
#  '@globeandmail',
#  '@gmbutts',
#  '@gop',
#  '@harleyrouda',
#  '@huffpost',
#  '@ipcc_ch',
#  '@jackthelad1947',
#  '@johnwdean',
#  '@junkscience',
#  '@kateraworth',
#  '@lindsayballant',
#  '@michaelemann',
#  '@mohamedghilan',
#  '@mrobertsqld',
#  '@msnbc',
#  '@neiltyson',
#  '@newyorkstateag',
#  '@overlapping',
#  '@pauledawson',
#  '@potus',
#  '@realdonaldtrump',
#  '@scottmorrisonmp',
#  '@secnielsen',
#  '@senatorleahy',
#  '@stevesgoddard',
#  '@superman4ever02',
#  '@tan123',
#  '@taraxandra',
#  '@themarketswork',
#  '@tumblindice1979',
#  '@usgcrp',
#  '@washingtonpost',
#  '@whitehouse',
#  'ac',
#  'accept',
#  'according',
#  'acknowledge',
#  'act',
#  'acting',
#  'action',
#  'actions',
#  'activists',
#  'acts',
#  'actually',
#  'adapt',
#  'addition',
#  'address',
#  'administration',
#  'advocate',
#  'affect',
#  'affected',
#  'affordable',
#  'afraid',
#  'age',
#  'agenda',
#  'ago',
#  'agree',
#  'agriculture',
#  'ahead',
#  'air',
#  'alarm',
#  'alarming',
#  'allow',
#  'amazing',
#  'america',
#  'american',
#  'americans',
#  'animal',
#  'animals',
#  'announced',
#  'appeals',
#  'arctic',
#  'area',
#  'aren',
#  "aren't",
#  'argument',
#  'article',
#  'asia',
#  'ask',
#  'asked',
#  'asking',
#  'aspects',
#  'assessment',
#  'atlantic',
#  'attack',
#  'attention',
#  'attribute',
#  'australia',
#  'authors',
#  'average',
#  'avoid',
#  'award',
#  'away',
#  'bad',
#  'bags',
#  'ball',
#  'banned',
#  'based',
#  'bbc',
#  'believe',
#  'believing',
#  'best',
#  'better',
#  'betting',
#  'big',
#  'biggest',
#  'billion',
#  'billions',
#  'bit',
#  'blame',
#  'blaming',
#  'bombshell',
#  'brain',
#  'break',
#  'breakdown',
#  'brexit',
#  'brilliant',
#  'bring',
#  'build',
#  'building',
#  'business',
#  'buy',
#  'called',
#  'calling',
#  'calls',
#  'came',
#  'campaign',
#  "can't",
#  'canada',
#  'canadians',
#  'candidates',
#  'capacity',
#  'capitalism',
#  'car',
#  'carbon',
#  'care',
#  'cared',
#  'cares',
#  'cars',
#  'case',
#  'cat',
#  'catastrophe',
#  'catastrophic',
#  'category',
#  'cause',
#  'caused',
#  'causes',
#  'causing',
#  'celsius',
#  'century',
#  'certain',
#  'challenge',
#  'chan',
#  'chance',
#  'chang',
#  'change',
#  "change'",
#  'changed',
#  'changes',
#  'changing',
#  'check',
#  'children',
#  'china',
#  'chinese',
#  'cities',
#  'city',
#  'class',
#  'clean',
#  'clear',
#  'climat',
#  'climate',
#  'climate-change',
#  'closer',
#  'cnn',
#  'co2',
#  'coal',
#  'coast',
#  'coastal',
#  'combat',
#  'come',
#  'comes',
#  'coming',
#  'comment',
#  'commitments',
#  'communism',
#  'communities',
#  'community',
#  'companies',
#  'compelling',
#  'completely',
#  'comprehensive',
#  'concerned',
#  'conference',
#  'congress',
#  'consequences',
#  'conservatism',
#  'consider',
#  'consumption',
#  'continue',
#  'continues',
#  'control',
#  'conversation',
#  'cooling',
#  'coral',
#  'corporate',
#  'corporations',
#  'cost',
#  'costs',
#  'countries',
#  'country',
#  'course',
#  'court',
#  'cover',
#  'coverage',
#  'crap',
#  'crayon',
#  'create',
#  'crisis',
#  'critical',
#  'crucial',
#  'current',
#  'currently',
#  'cut',
#  'cuts',
#  'cutting',
#  'daily',
#  'damage',
#  'damn',
#  'danger',
#  'dangerous',
#  'dangers',
#  'data',
#  'day',
#  'days',
#  'dead',
#  'deadly',
#  'deal',
#  'dealing',
#  'dear',
#  'death',
#  'debate',
#  'decade',
#  'decades',
#  'decision',
#  'degree',
#  'degrees',
#  'democrats',
#  'denial',
#  'denier',
#  'deniers',
#  'deny',
#  'denying',
#  'despite',
#  'destroyed',
#  'destroying',
#  'destruction',
#  'devastating',
#  'developed',
#  'di',
#  'did',
#  'didn',
#  "didn't",
#  'die',
#  'diets',
#  'difference',
#  'diminish',
#  'dioxide',
#  'dire',
#  'direct',
#  'disaster',
#  'disasters',
#  'discussing',
#  'discussion',
#  'displace',
#  'ditch',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'donald',
#  'dont',
#  'doubt',
#  'dr',
#  'drastic',
#  'drastically',
#  'drew',
#  'drive',
#  'drought',
#  'droughts',
#  'dumb',
#  'dumbass',
#  'dutch',
#  'dying',
#  'early',
#  'earth',
#  'eat',
#  'eating',
#  'eco',
#  'economic',
#  'economics',
#  'economy',
#  'education',
#  'effective',
#  'effects',
#  'effort',
#  'election',
#  'electric',
#  'electricity',
#  'emergency',
#  'emissions',
#  'encourage',
#  'end',
#  'energy',
#  'ensure',
#  'entire',
#  'environment',
#  'environmental',
#  'environmentalist',
#  'especially',
#  'essential',
#  'essentially',
#  'europe',
#  'event',
#  'events',
#  'everybody',
#  'everyday',
#  'evidence',
#  'exactly',
#  'exist',
#  'existence',
#  'existing',
#  'expert',
#  'experts',
#  'extent',
#  'extinction',
#  'extreme',
#  'face',
#  'facing',
#  'fact',
#  'facts',
#  'failed',
#  'failing',
#  'failure',
#  'fairness',
#  'fake',
#  'fall',
#  'fantastic',
#  'far',
#  'farce',
#  'fat',
#  'fear',
#  'fed',
#  'feel',
#  'felt',
#  'fema',
#  'fight',
#  'fighting',
#  'fires',
#  'fix',
#  'fl',
#  'flooding',
#  'floods',
#  'florida',
#  'floridians',
#  'focused',
#  'folks',
#  'following',
#  'food',
#  'ford',
#  'forest',
#  'forests',
#  'forever',
#  'forget',
#  'forum',
#  'fossil',
#  'fourth',
#  'fracking',
#  'fraud',
#  'free',
#  'frequency',
#  'friends',
#  'fuck',
#  'fucked',
#  'fucking',
#  'fuel',
#  'fuels',
#  'fun',
#  'fund',
#  'future',
#  'gas',
#  'general',
#  'generation',
#  'generations',
#  'genocide',
#  'georgia',
#  'gets',
#  'getting',
#  'given',
#  'glad',
#  'global',
#  'god',
#  'goes',
#  'going',
#  'gonna',
#  'good',
#  'gop',
#  'gore',
#  'got',
#  'gotta',
#  "gov't",
#  'gove',
#  'governance',
#  'government',
#  "government's",
#  'governments',
#  'governor',
#  'govt',
#  'great',
#  'greater',
#  'green',
#  'greenhouse',
#  'group',
#  'grow',
#  'growth',
#  'guess',
#  'guilt',
#  'gun',
#  'guy',
#  'guys',
#  'habitat',
#  'half',
#  'hand',
#  'happen',
#  'happening',
#  'happens',
#  'happy',
#  'hard',
#  'harmless',
#  'hate',
#  'hates',
#  'having',
#  "he's",
#  'head',
#  'health',
#  'healthcare',
#  'hear',
#  'hearing',
#  'heat',
#  'hell',
#  'hello',
#  'help',
#  "here's",
#  'hewson',
#  'hey',
#  'high',
#  'higher',
#  'history',
#  'hit',
#  'hits',
#  'hitting',
#  'hoax',
#  'home',
#  'homes',
#  'hope',
#  'hoping',
#  'hot',
#  'hour',
#  'hours',
#  'house',
#  'ht',
#  'htt',
#  'http',
#  'https',
#  'huge',
#  'human',
#  'humanity',
#  'humans',
#  'hurricane',
#  'hurricanes',
#  'hypocrite',
#  'hysteria',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'ice',
#  'idea',
#  'idiot',
#  'idiots',
#  'ignore',
#  'ignoring',
#  'imagine',
#  'immediate',
#  'immigration',
#  'impact',
#  'impacting',
#  'impacts',
#  'important',
#  'increase',
#  'increasing',
#  'individual',
#  'industrial',
#  'industries',
#  'industry',
#  'inequality',
#  'info',
#  'infrastructure',
#  'instead',
#  'insurance',
#  'intellect',
#  'intense',
#  'interested',
#  'interesting',
#  'interests',
#  'intergovernmental',
#  'invest',
#  'investors',
#  'ipcc',
#  'irish',
#  'irreversible',
#  'island',
#  'islands',
#  'isn',
#  "isn't",
#  'issue',
#  'issues',
#  "it's",
#  'jesus',
#  'jobs',
#  'john',
#  'join',
#  'just',
#  'justice',
#  'kavanaugh',
#  'keeping',
#  'kid',
#  'kids',
#  'kill',
#  'kind',
#  'know',
#  'knows',
#  'labor',
#  'lack',
#  'land',
#  'landfall',
#  'landmark',
#  'largest',
#  'late',
#  'latest',
#  'lawson',
#  'lead',
#  'leader',
#  'leaders',
#  'leadership',
#  'leading',
#  'learn',
#  'learned',
#  'leave',
#  'leaves',
#  'left',
#  'leong',
#  'let',
#  "let's",
#  'lets',
#  'level',
#  'levels',
#  'liberal',
#  'liberals',
#  'life',
#  'lifetime',
#  'like',
#  'likely',
#  'limit',
#  'limiting',
#  'link',
#  'literally',
#  'little',
#  'live',
#  'lives',
#  'living',
#  'll',
#  'lnp',
#  'local',
#  'long',
#  'longer',
#  'look',
#  'looking',
#  'looming',
#  'lord',
#  'lost',
#  'lot',
#  'love',
#  'low',
#  'lying',
#  'major',
#  'make',
#  'makes',
#  'making',
#  'man',
#  'man-made',
#  'marine',
#  'markets',
#  'mass',
#  'massive',
#  'matter',
#  'matters',
#  'maybe',
#  'mean',
#  'means',
#  'meat',
#  'meat-eating',
#  'media',
#  'meet',
#  'meeting',
#  'melting',
#  'men',
#  'mental',
#  'message',
#  'metal',
#  'michael',
#  'middle',
#  'military',
#  'million',
#  'mind',
#  'mitigate',
#  'model',
#  'models',
#  'monday',
#  'money',
#  'monster',
#  'month',
#  'months',
#  'moral',
#  'morning',
#  'morrison',
#  'mph',
#  'mr',
#  'myth',
#  'narrative',
#  'nation',
#  'national',
#  'nationalism',
#  'nations',
#  'natural',
#  'nature',
#  'need',
#  'needed',
#  'needs',
#  'negative',
#  'new',
#  'news',
#  'nice',
#  'night',
#  'nobel',
#  'normal',
#  'north',
#  'nov',
#  'november',
#  'obama',
#  'ocean',
#  'oct',
#  'october',
#  'office',
#  'oh',
#  'oil',
#  'ok',
#  'old',
#  'ominous',
#  'ontario',
#  'opinion',
#  'opportunity',
#  'order',
#  'organization',
#  'oxt40bgdvo',
#  'panel',
#  'panhandle',
#  'panic',
#  'paper',
#  'paris',
#  'party',
#  'pass',
#  'past',
#  'path',
#  'pay',
#  'paying',
#  'peak',
#  'people',
#  'percent',
#  'person',
#  'phase',
#  'phrase',
#  'pick',
#  'piece',
#  'place',
#  'places',
#  'plan',
#  'planet',
#  'planning',
#  'plans',
#  'plant',
#  'plants',
#  'plastic',
#  'pls',
#  'pm',
#  'point',
#  'points',
#  'policies',
#  'policy',
#  'political',
#  'politicians',
#  'politicizing',
#  'politics',
#  'pollute',
#  'polluters',
#  'pollution',
#  'population',
#  'possible',
#  'post',
#  'potential',
#  'poverty',
#  'power',
#  'powerful',
#  'ppl',
#  'predict',
#  'predicted',
#  'predictions',
#  'present',
#  'president',
#  'pretend',
#  'pretty',
#  'prevent',
#  'price',
#  'prices',
#  'pricing',
#  'prize',
#  'problem',
#  'problems',
#  'produce',
#  'produced',
#  'profit',
#  'program',
#  'progress',
#  'progressive',
#  'project',
#  'projected',
#  'projects',
#  'proof',
#  'protect',
#  'protecting',
#  'proud',
#  'prove',
#  'provide',
#  'public',
#  'published',
#  'push',
#  'question',
#  'quick',
#  'quickly',
#  'quite',
#  'racist',
#  'radio',
#  'rain',
#  'rapid',
#  'rapidly',
#  'rd',
#  'reaching',
#  'read',
#  'real',
#  'reality',
#  'really',
#  'reason',
#  'recent',
#  'record',
#  'recycle',
#  'red',
#  'reduce',
#  'reducing',
#  'reductions',
#  'reef',
#  'reefs',
#  'reform',
#  'refuse',
#  'regional',
#  'related',
#  'released',
#  'remember',
#  'remind',
#  'reminder',
#  'renewable',
#  'renewables',
#  'repair',
#  'replies',
#  'report',
#  'republican',
#  'republicans',
#  'require',
#  'research',
#  'resource',
#  'respond',
#  'response',
#  'responsible',
#  'rest',
#  'result',
#  'return',
#  'retweet',
#  'reusable',
#  'reverse',
#  'revolution',
#  'rewards',
#  'rich',
#  'richard',
#  'rick',
#  'right',
#  'rights',
#  'rise',
#  'risen',
#  'rising',
#  'risk',
#  'risks',
#  'road',
#  'roll',
#  'run',
#  'runaway',
#  'running',
#  'sad',
#  'sadly',
#  'said',
#  'sake',
#  'save',
#  'saw',
#  'say',
#  'saying',
#  'says',
#  'scarcity',
#  'scared',
#  'scary',
#  'scenario',
#  'school',
#  'schools',
#  'science',
#  'scientific',
#  'scientist',
#  'scientists',
#  'scott',
#  'sea',
#  'security',
#  'seeing',
#  'seen',
#  'senate',
#  'send',
#  'seriously',
#  'set',
#  'setting',
#  'severe',
#  'sexy',
#  'sharma',
#  'shit',
#  'shopping',
#  'short',
#  'showed',
#  'significant',
#  'simple',
#  'single',
#  'skips',
#  'slash',
#  'slow',
#  'small',
#  'social',
#  'society',
#  'solutions',
#  'solve',
#  'solving',
#  'soon',
#  'sorry',
#  'sort',
#  'sounds',
#  'south',
#  'space',
#  'speaking',
#  'special',
#  'species',
#  'speech',
#  'st',
#  'start',
#  'started',
#  'starting',
#  'starts',
#  'state',
#  'states',
#  'stay',
#  'step',
#  'steps',
#  'stop',
#  'stories',
#  'storm',
#  'storms',
#  'story',
#  'strange',
#  'straw',
#  'strong',
#  'strongest',
#  'students',
#  'study',
#  'stuff',
#  'stupid',
#  'success',
#  'suck',
#  'suggesting',
#  'suggests',
#  'summer',
#  'summit',
#  'super',
#  'support',
#  'suppose',
#  'sure',
#  'survive',
#  'swap',
#  'switch',
#  'tackle',
#  'tackling',
#  'taken',
#  'takes',
#  'taking',
#  'talk',
#  'talker',
#  'talking',
#  'targets',
#  'tax',
#  'technologies',
#  'tell',
#  'telling',
#  ...]

# %% [markdown]
# ### evaluation

# %%
def eval_results(predicted_y_test, y_test):
    accuracy_s = accuracy_score(y_test, predicted_y_test)
    precision_s = precision_score(y_test, predicted_y_test)
    recall_s = recall_score(y_test, predicted_y_test)
    f1_s = f1_score(y_test, predicted_y_test)
    cm = confusion_matrix(y_test, predicted_y_test)  
    
    print('Accuracy Score:', accuracy_s)
    print("Precision Score:", precision_s)
    print("Recall Score:", recall_s)
    print("f1 Score:", f1_s)
    print('confusion_matrix is: \n', cm, '\n')
    print(classification_report(y_test, predicted_y_test))
    
    classes = ['not supportive', 'supportive']
    sns.heatmap(cm, annot=True, cmap='Blues', yticklabels=classes, xticklabels=classes)
    plt.show()
    return accuracy_s, precision_s, recall_s, f1_s, cm

# %% [markdown]
# ### k-fold

# %%
def k_fold_evaluate(X, y, X_col, y_col, vect, clf):
    # initialization
    accuracy = []
    precision = []
    recall=[]
    f1 = []
    fold = 1
    skf = StratifiedKFold(n_splits=5, random_state=1, shuffle= True)
    
    # build model and collect results
    for train_index, test_index in skf.split(X, y):
        if fold==1:
            list(map(lambda x: check(x, train_index, y_col=y_col), range(2)))
            list(map(lambda x: check(x, test_index, note='testing', y_col=y_col), range(2)))
        
        X_train, X_test, y_train, y_test = custom_split(train_index, test_index, x_col=X_col, y_col=y_col)
        
        predicted_y_test = classifier(X_train=X_train, y_train=y_train, 
                                      X_test=X_test, fold=fold,
                                      vect = vect,
                                      clf = clf)
        
        print('\nFold: {}'.format(fold))
        accuracy_s, precision_s, recall_s, f1_s, cm = eval_results(predicted_y_test, y_test)
        
        accuracy.append(accuracy_s)
        precision.append(precision_s)
        recall.append(recall_s)
        f1.append(f1_s)
        
        metrics_df = pd.DataFrame(
                    {
                        'accuracy': accuracy,
                        'precision': precision,
                        'recall':recall,
                        'f1':f1
                    }
                )
        fold += 1
    return metrics_df

# %% [markdown]
# ### test

# %%
vect = CountVectorizer(token_pattern="(?!RT|rt|\d+)[@#]*[\w\'_-]{2,100}",
                                     analyzer = 'word',
                                     stop_words='english',
                                     min_df = 3)
vect = TfIdfWord2VecVectorizer()
clf = DecisionTreeClassifier(criterion='entropy',
                                           random_state = 100,
                                           max_depth = 35,
                                           min_samples_leaf = 3)
k_fold_evaluate(X, y, X_col='text', y_col='target', vect=vect, clf=clf)
# Out:
# There are 639999 negative tweets in the training set.
# There are 640000 positive tweets in the training set.
# There are 160000 negative tweets in the testing set.
# There are 160000 positive tweets in the testing set.

# %% [markdown]
# ### reload pickle

# %%
clf2 = joblib.load('ClimateTeam7PD1.pkl')
y_pred = clf2.predict(X)
f1_score(y, y_pred)
# Out:
# 0.7355096602265155
