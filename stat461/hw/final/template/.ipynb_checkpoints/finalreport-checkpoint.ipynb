# %% [markdown]
# ## Abstract

# %% [markdown]
# ## Introduction

# %% [markdown]
# ## Data Set

# %%
day_in_week = c(
              rep("Mon", 3),
              rep("Tues", 3),
              rep("Wed", 3),
              rep("Thurs", 3),
              rep("Fri", 3),
              rep("Sat", 3),
              rep("Sun", 3))
location = rep(c('Pattee', 'Hub', 'DownTown'), 7)
num_of_people_in_line = c(24, 20, 5, 
                          20, 18, 6, 
                          18, 17, 4,
                          22, 20, 6,
                          25, 22, 8,
                          15, 12, 3,
                          16, 10, 4)
df = data.frame(day_in_week, location, num_of_people_in_line)
df
# Out:
#    day_in_week location num_of_people_in_line
# 1  Mon         Pattee   24
# 2  Mon         Hub      20
# 3  Mon         DownTown  5
# 4  Tues        Pattee   20
# 5  Tues        Hub      18
# 6  Tues        DownTown  6
# 7  Wed         Pattee   18
# 8  Wed         Hub      17
# 9  Wed         DownTown  4
# 10 Thurs       Pattee   22
# 11 Thurs       Hub      20
# 12 Thurs       DownTown  6
# 13 Fri         Pattee   25
# 14 Fri         Hub      22
# 15 Fri         DownTown  8
# 16 Sat         Pattee   15
# 17 Sat         Hub      12
# 18 Sat         DownTown  3
# 19 Sun         Pattee   16
# 20 Sun         Hub      10
# 21 Sun         DownTown  4

# %% [markdown]
# ## Exploratory data analysis

# %% [markdown]
# ### Basic plots

# %% [markdown]
# #### 1

# %%
library(ggplot2)
library(plyr)

df_ply <- ddply(df, .(day_in_week), transform, pos = cumsum(num_of_people_in_line) - (0.5 * num_of_people_in_line)) 
df_ply$day_in_week_adjusted = factor(df_ply$day_in_week, levels=c('Mon','Tues','Wed','Thurs','Fri','Sat','Sun'))
df_ply
# Out:
#    day_in_week location num_of_people_in_line pos  day_in_week_adjusted
# 1  Fri         Pattee   25                    12.5 Fri
# 2  Fri         Hub      22                    36.0 Fri
# 3  Fri         DownTown  8                    51.0 Fri
# 4  Mon         Pattee   24                    12.0 Mon
# 5  Mon         Hub      20                    34.0 Mon
# 6  Mon         DownTown  5                    46.5 Mon
# 7  Sat         Pattee   15                     7.5 Sat
# 8  Sat         Hub      12                    21.0 Sat
# 9  Sat         DownTown  3                    28.5 Sat
# 10 Sun         Pattee   16                     8.0 Sun
# 11 Sun         Hub      10                    21.0 Sun
# 12 Sun         DownTown  4                    28.0 Sun
# 13 Thurs       Pattee   22                    11.0 Thurs
# 14 Thurs       Hub      20                    32.0 Thurs
# 15 Thurs       DownTown  6                    45.0 Thurs
# 16 Tues        Pattee   20                    10.0 Tues
# ...

# %%
# Plotting
ggplot(df_ply, aes(x = location, y = num_of_people_in_line)) + 
  geom_bar(stat="identity") + 
  facet_grid(.~day_in_week_adjusted) +
  ylab('Number of people standing in line') + 
  xlab('Location of Starbucks on campus') +
  theme(axis.text.x = element_text(angle = 90, size = 8))
# Out:
# plot without title

# %% [markdown]
# ### Interaction Plot

# %%
interaction.plot(x.factor = df$location, trace.factor = df$day_in_week,
                response = df$num_of_people_in_line, type ="b",col = 2:3,
                xlab ="Location of StarBucks", ylab ="Number of People standing in the Starbucks line",
                trace.label ="concentration")
# Out:
# plot without title

# %% [markdown]
# ## Modeling

# %% [markdown]
# ### Description

# %% [markdown]
# ### Data Model

# %% [markdown]
# ## Result

# %% [markdown]
# ## Conclusion
